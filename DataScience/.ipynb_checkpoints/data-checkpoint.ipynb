# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_school_info = pd.read_excel('./data/학교알리미/2023년_학교기본정보_부산광역시교육청.xlsx')
df_school_info["지역"] = df_school_info["지역"].replace("부산광역시 ", "")
df_school_info.head()
# Out:
#       시도교육청         지역교육청         지역   정보공시 학교코드            학교명  학교급코드 설립구분  \
# 0       교육부  부산광역시동래교육지원청  부산광역시 연제구  S000003559  부산교육대학교부설초등학교      2   국립
# 1  부산광역시교육청  부산광역시서부교육지원청   부산광역시 중구  S020000625         광일초등학교      2   공립
# 2  부산광역시교육청  부산광역시서부교육지원청   부산광역시 중구  S020000626         남성초등학교      2   사립
# 3  부산광역시교육청  부산광역시남부교육지원청   부산광역시 남구  S020000628         대남초등학교      2   공립
# 4  부산광역시교육청  부산광역시남부교육지원청   부산광역시 남구  S020000629         대연초등학교      2   공립
#
#    학교특성 분교여부 설립유형  ...    우편번호  학교도로명 우편번호                  학교도로명 주소  \
# 0   NaN    N   부설  ...  611736     47503.0          부산광역시 연제구 교대로 24
# 1   NaN    N   단설  ...  600801     48933.0           부산광역시 중구 중구로 74
# 2   NaN    N   단설  ...  600091     48926.0            부산광역시 중구 샘길 14
# 3   NaN    N   단설  ...  608020     48428.0  부산광역시 남구 황령대로 343번길 9-55
# 4   NaN    N   단설  ...  608807     48441.0       부산광역시 남구 진남로18번길 11
#
#       학교도로명 상세주소         위도          경도          전화번호          팩스번호  \
# 0          (거제동)  35.194573  129.075497  051-550-2800  051-505-9122
# 1        (대청동4가)  35.104005  129.029866  051-603-5000  051-603-5119
# 2        (대청동1가)  35.104111  129.032386  051-469-7963  051-469-7965
# 3  (대연동, 대남초등학교)  35.148857  129.097236  051-622-9434  051-633-9436
# 4  (대연동, 대연초등학교)  35.137103  129.092284  051-610-7600  051-627-6494
#
#                    홈페이지 남녀공학구분
# 0  http://es.bnue.ac.kr   남녀공학
# 1     www.gwangil.es.kr   남녀공학
# 2           www.nisb.kr   남녀공학
# 3  http://daenam.es.kr/   남녀공학
# 4     www.daeyeon.es.kr   남녀공학
#
# [5 rows x 26 columns]

# %%
plt.figure(figsize=(20,5))

# 한글이 깨지는 오류를 수정하기 위해 아래와 같은 코드 첨부
plt.rcParams['font.family'] = 'NanumGothic'
# df_school_info의 지역을 기준으로 groupby 진행 후 해당 지역에 대한 count를 새 column으로 지정해줌
df_school_info_group_by_city = df_school_info[["지역"]].groupby(["지역"])["지역"].count().sort_values(ascending=False).reset_index(name="count")

sns.barplot(data=df_school_info_group_by_city, x="지역", y="count")
# Out:
# <Axes: xlabel='지역', ylabel='count'>
